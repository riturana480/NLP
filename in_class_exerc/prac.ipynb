# %%
import re

text = """
Visit http://example.com
Also see https://google.com
"""

pattern = r'https?://\S+'
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['http://example.com', 'https://google.com']

# %%
text = "Hello! Welcome to NLP class, class 2026."
#find for empty space.
pattern = r'\w+'

matches = re.findall(pattern, text)
print(matches)
# Out:
# ['Hello', 'Welcome', 'to', 'NLP', 'class', 'class', '2026']

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/ritu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/ritu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = "The price is $100.00 for this item."
tokens = word_tokenize(text)
stopwords_list = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stopwords_list]
print(filtered_tokens)
# Out:
# ['price', '$', '100.00', 'item', '.']

# %%
text = "The sky is blue and grey and black at 13:45 hours."
tokens = word_tokenize(text)
stopwords_list = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stopwords_list]
print(filtered_tokens)
# Out:
# ['sky', 'blue', 'grey', 'black', '13:45', 'hours', '.']

# %%
text = "The sky is not blue and grey and black at 13:45 hours."
tokens = word_tokenize(text)
stopwords_list = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stopwords_list]
print(filtered_tokens)
# Out:
# ['sky', 'blue', 'grey', 'black', '13:45', 'hours', '.']

# %%
text = "I neither nor or  like apples nor oranges, and I do not want either."
tokens = word_tokenize(text)

stopwords_list = set(stopwords.words('english'))
#stopwords_list.difference_update({'neither', 'nor', 'or', 'not'})

filtered_tokens = [word for word in tokens if word.lower() not in stopwords_list]
print(filtered_tokens)
# Out:
# ['neither', 'like', 'apples', 'oranges', ',', 'want', 'either', '.']

# %%
from nltk.stem import SnowballStemmer
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
porter = PorterStemmer()
snowball = SnowballStemmer('english')
lancaster = LancasterStemmer()

words = ["running", "runner", "university", "destructive", "reluctant"]
print("Porter Stemmer:")
for word in words:
    print(f"{word} -> {porter.stem(word)}")
print("\nSnowball Stemmer:")
for word in words:
    print(f"{word} -> {snowball.stem(word)}")
print("\nLancaster Stemmer:")
for word in words:
    print(f"{word} -> {lancaster.stem(word)}")
# Out:
# Porter Stemmer:
# running -> run
# runner -> runner
# university -> univers
# destructive -> destruct
# reluctant -> reluct
#
# Snowball Stemmer:
# running -> run
# runner -> runner
# university -> univers
# destructive -> destruct
# reluctant -> reluct
#
# Lancaster Stemmer:
# running -> run
# runner -> run
# university -> univers
# destructive -> destruct
# reluctant -> reluct

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
words = ["delayed", "tracking", "working", "cancelled", "refund", "Sehr" , "schlechter" , "Kundenservice"]
print("WordNet Lemmatizer:")
for word in words:
    print(f"{word} -> {lemmatizer.lemmatize(word)}")
# Out:
# WordNet Lemmatizer:
# delayed -> delayed
# tracking -> tracking
# working -> working
# cancelled -> cancelled
# refund -> refund
# Sehr -> Sehr
# schlechter -> schlechter
# Kundenservice -> Kundenservice
# [nltk_data] Downloading package wordnet to /Users/ritu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/ritu/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
pip --version
# Out:
# pip 26.0.1 from /Users/ritu/Documents/Semester 2/NLP/.venv/lib/python3.9/site-packages/pip (python 3.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 2.1 MB/s  0:00:03 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.7/656.7 kB 3.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.1/788.1 kB 6.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [spacy]m14/15 [spacy]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
spacy.cli.download('de_core_news_sm')
nlp = spacy.load( 'de_core_news_sm')
word = ["Sehr schlechter Kundenservice"]
doc = nlp(word)
print("Token".ljust(15), "Lemma".ljust(15))
for token in doc:
    print(f"{token.text.ljust(15)} {token.lemma_.ljust(15)}")
# Out:
# ...
#   Using cached de_core_news_sm-3.8.0-py3-none-any.whl (14.6 MB)
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import spacy
# ----> 2 spacy.cli.download('de_core_news_sm')
#       3 nlp = spacy.load( 'de_core_news_sm')
#       4 word = ["Sehr schlechter Kundenservice"]
#
# File /opt/anaconda3/lib/python3.13/site-packages/spacy/cli/download.py:101, in download(model, direct, sdist, custom_url, *pip_args)
#      97     version = get_version(model_name, compatibility)
#      99 filename = get_model_filename(model_name, version, sdist)
# --> 101 download_model(filename, pip_args, custom_url)
#     102 msg.good(
#     103     "Download and installation successful",
#     104     f"You can now load the package via spacy.load('{model_name}')",
#     105 )
#     106 if is_in_jupyter():
#
# ...

# %%
import re

text = """
 https://twitter.com/teslarati and https://twitter.com/dummy_tesla
and https://twitter.com/dummy_2_tesla
"""

#pattern = r'https://twitter\.com/(\w+)'
pattern = r'http?s://twitter\.com/(\w+)'
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['teslarati', 'dummy_tesla', 'dummy_2_tesla']

# %%
import re

text = """
 OMGGG 😭😭 my flight from FRA → DEL got delayed AGAIN!!! #Lufthansa @airporthelp
"""

pattern = r''
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['airporthelp']
